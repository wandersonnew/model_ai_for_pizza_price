# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pickle

# %%
df = pd.read_csv('pizzas.csv')
print(df.head())
# Out:
#    diametro  preco
# 0        20     50
# 1        22     55
# 2        24     60
# 3        26     65
# 4        28     70

# %%
df.plot(kind='scatter', x='diametro', y='preco')
plt.show()

# %%
model = LinearRegression()

# %%
X = df[['diametro']]
y = df[['preco']]

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
with open('pizza_price_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
model.predict([[30]])
# Out:
# c:\Users\wande\Documents\PrecoPizza\model_ai_for_pizza_price\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[75.]])

# %%
model.predict([[110]])
# Out:
# c:\Users\wande\Documents\PrecoPizza\model_ai_for_pizza_price\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[275.]])
